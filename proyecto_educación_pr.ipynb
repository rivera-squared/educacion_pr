# %%
import numpy as np
import pandas as pd
import scipy as sp

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Información de escuelas de PR
#
# ## Año Escolar 2018-19

# %%
maestros = pd.read_csv('/Users/edwardriverarivera/Documents/educacion_workingFolder/master_draft.csv')
maestros
# Out:
#     ANO_ESCOLAR  CODIGO_ESCUELA    region      municipio  \
# 0       2018-19           15784   ARECIBO        ARECIBO
# 1       2018-19           74807   ARECIBO      VEGA BAJA
# 2       2018-19           17467   ARECIBO          CAMUY
# 3       2018-19           71886   ARECIBO      VEGA BAJA
# 4       2018-19           10637   ARECIBO        ARECIBO
# ..          ...             ...       ...            ...
# 814     2018-19           69112  SAN JUAN  TRUJILLO ALTO
# 815     2018-19           69054  SAN JUAN  TRUJILLO ALTO
# 816     2018-19           62968  SAN JUAN       SAN JUAN
# 817     2018-19           65557  SAN JUAN       SAN JUAN
# 818     2018-19           61564  SAN JUAN       SAN JUAN
#
#                            escuela  escuela_receptora       nivel  matricula  \
# 0          Abelardo Martinez Otero                  0    superior        423
# 1          Agapito Rosario Rosario                  1   elemental        565
# ...

# %% [markdown]
# ## Escuelas por región

# %%
region = maestros.iloc[:,2]
region.value_counts()
# Out:
# PONCE       136
# SAN JUAN    126
# HUMACAO     120
# CAGUAS      117
# MAYAGUEZ    112
# BAYAMON     109
# ARECIBO      99
# Name: region, dtype: int64

# %%
municipio = maestros.iloc[:, 3]
municipio.value_counts()
# Out:
# SAN JUAN       79
# PONCE          39
# BAYAMON        39
# CAGUAS         31
# CAROLINA       24
#                ..
# CEIBA           4
# MARICAO         4
# HORMIGUEROS     4
# RINCON          3
# CULEBRA         1
# Name: municipio, Length: 78, dtype: int64
